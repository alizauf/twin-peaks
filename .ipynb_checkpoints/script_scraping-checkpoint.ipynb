# %%
from bs4 import BeautifulSoup
import urllib
import re

# %%
r = urllib.urlopen('http://www.glastonberrygrove.net/texts/script9.html').read()
soup = BeautifulSoup(r, 'html.parser')

# %%
script = soup.get_text()
print script
# Out:
# Twin Peaks Episode #2.002
#
#   <!--
#   FONT      { font-family:arial,helvetica;font-size:1em}
#   .title    { font-family:arial,helvetica;font-weight:bold;font-size:1.4em}
#   .small    { font-family:arial,helvetica;font-size:.7em}
#   .red      { font-family:arial,helvetica;color:#DD0000}
#   .gold     { font-family:arial,helvetica;color:#FFAA00}
#   B         { font-family:arial,helvetica;font-weight:bold}
#   A:link    { color:#FFAA00;text-decoration:none}
#   A:visited	{ color:#FFAA00;text-decoration:none}
#   A:hover	{ color:#339933;text-decoration:none}
#   .L1   	{ color:#FFAA00;font-weight:bold;font-size:1em}
#   // -->
#
#
#
#
#
#
#
#
#
#
#
#
# TWIN PEAKS
# #2.002
#
#
#
# story by
# Harley Peyton
#
#
#
#
# Download as a PDF
#
#
#
#
#
#
#       Scanned by runningdog.
#       Original formatting duplicated as closely as possible. For clarification all duplicate
#       pages removed. Revised lines are red
#       and the new lines will be gold.
# ...

# %%
print soup
# Out:
# <html>
# <head>
# <title>Twin Peaks Episode #2.001</title>
# <style type="text/css">
#   <!--
#   FONT      { font-family:arial,helvetica;font-size:1em}
#   .title    { font-family:arial,helvetica;font-weight:bold;font-size:1.4em}
#   .small    { font-family:arial,helvetica;font-size:.7em}
#   .red      { font-family:arial,helvetica;color:#DD0000}
#   .gold     { font-family:arial,helvetica;color:#FFAA00}
#   B         { font-family:arial,helvetica;font-weight:bold}
#   A:link    { color:#FFAA00;text-decoration:none}
#   A:visited	{ color:#FFAA00;text-decoration:none}
#   A:hover	{ color:#339933;text-decoration:none}
#   .L1   	{ color:#FFAA00;font-weight:bold;font-size:1em}
#   // -->
#   </style>
# </head>
# <body background="curtain.gif" bgcolor="#000000" leftmargin="0" link="#DD0000" marginheight="0" marginwidth="0" text="#339933" topmargin="0" vlink="#339933">
# <center>
# <table border="0" cellpadding="0" cellspacing="0" width="95%">
# <tr>
# <td>
# <br>
# <br>
# <center>
# ...

# %%
#This gets the scenes
re.findall('\n(\d.*)\n', script)
# Out:
# [u'7700 Balboa Blvd',
#  u'1. INT. GREAT NORTHERN DINING ROOM - DAY',
#  u'2. INT. GREAT NORTHERN CORRIDOR - NIGHT',
#  u'3. INT. GREAT NORTHERN DINING ROOM - DAY',
#  u'4. EXT. HOSPITAL - DAY',
#  u"4. INT. RONETTE PULASKI'S HOSPITAL ROOM - DAY",
#  u"6: EXT. ONE-EYED JACK'S - DAY",
#  u"7: INT. ONE-EYED JACK'S - DAY",
#  u'8. EXT. APARTMENT HOUSE - DAY',
#  u'9. INT. TREMOND APARTMENT - DAY',
#  u'10. EXT. APARTMENT HOUSE - DAY',
#  u"11. INT. BEN HORNE'S OFFICE - DAY",
#  u'12. EXT. BLUE PINE LODGE - DAY',
#  u'13. INT. BLUE PINE LODGE - DAY',
#  u'14. INT. BLUE PINE LODGE KITCHEN - DAY',
#  u'15. INT. BLUE PINE LODGE - DAY',
#  u'16. INT. THE DOUBLE R DINER - DAY',
#  u'17. INT. DINER - DAY',
#  u'18. INT. THE DOUBLE R DINER - DAY',
#  u'21. INT. THE DOUBLE R DINER - DAY',
#  u"22. EXT. SHERIFF'S STATION - DAY",
#  u"23. INT. SHERIFF'S STATION - DAY",
#  u"24. INT. SHERIFF TRUMAN'S OFFICE - DAY",
#  u"25. INT. SHERIFF'S STATION - DAY",
#  u'26. INT. HOSPITAL ROOM - DAY',
# ...

# %%
#this one gives you everything including the continued and voices and cut to
re.findall('\n(\d.+|[A-Z ()\':]+)\n', script)
# Out:
# [u'  ',
#  u'TWIN PEAKS',
#  u'      ',
#  u'7700 Balboa Blvd',
#  u'REVISIONS:',
#  u'ACT ONE',
#  u'FADE IN:',
#  u'1. INT. GREAT NORTHERN DINING ROOM - DAY',
#  u'CUT TO:',
#  u'2. INT. GREAT NORTHERN CORRIDOR - NIGHT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'CUT TO:',
#  u'3. INT. GREAT NORTHERN DINING ROOM - DAY',
#  u'CUT TO:',
#  u'4. EXT. HOSPITAL - DAY',
#  u'CUT TO:',
#  u"4. INT. RONETTE PULASKI'S HOSPITAL ROOM - DAY",
#  u'COOPER',
#  u'COOPER',
#  u'COOPER',
#  u'COOPER',
#  u'TRUMAN',
#  u'COOPER',
#  u'TRUMAN',
#  u'COOPER',
# ...

# %%
scenes_chars = re.findall('\n(\d.+|[A-Z ]+)\n', script)

# %% [markdown]
# Idea.... if I have a scene with no discussion, look for characters names?

# %%
for a in scenes_chars:
    print a
# Out:
#
# TWIN PEAKS
#
# 7700 Balboa Blvd
# ACT ONE
# 1. INT. GREAT NORTHERN DINING ROOM - DAY
# 2. INT. GREAT NORTHERN CORRIDOR - NIGHT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# ALBERT
# COOPER
# 3. INT. GREAT NORTHERN DINING ROOM - DAY
# 4. EXT. HOSPITAL - DAY
# 4. INT. RONETTE PULASKI'S HOSPITAL ROOM - DAY
# COOPER
# COOPER
# COOPER
# COOPER
# TRUMAN
# COOPER
# TRUMAN
# COOPER
# COOPER
# COOPER
#  ANGLE ON PAPER
#  BACK TO SCENE
# TRUMAN
# 6: EXT. ONE-EYED JACK'S - DAY
# 7: INT. ONE-EYED JACK'S - DAY
# AUDREY
# NANCY
# AUDREY
# NANCY
# AUDREY
# NANCY
# AUDREY
# AUDREY
# NANCY
# AUDREY
# NANCY
# AUDREY
# AUDREY
# READING GIRL
# 8. EXT. APARTMENT HOUSE - DAY
# DONNA
# VOICE
# 9. INT. TREMOND APARTMENT - DAY
# TREMOND
# DONNA
# TREMOND
# TREMOND
# ...

# %% [markdown]
# Want to extract scene, time of day, character list from each scene.

# %%
scenes_chars
# Out:
# [u'  ',
#  u'TWIN PEAKS',
#  u'      ',
#  u'7700 Balboa Blvd',
#  u'ACT ONE',
#  u'1. INT. GREAT NORTHERN DINING ROOM - DAY',
#  u'2. INT. GREAT NORTHERN CORRIDOR - NIGHT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'ALBERT',
#  u'COOPER',
#  u'3. INT. GREAT NORTHERN DINING ROOM - DAY',
#  u'4. EXT. HOSPITAL - DAY',
#  u"4. INT. RONETTE PULASKI'S HOSPITAL ROOM - DAY",
#  u'COOPER',
#  u'COOPER',
#  u'COOPER',
#  u'COOPER',
#  u'TRUMAN',
#  u'COOPER',
#  u'TRUMAN',
#  u'COOPER',
#  u'COOPER',
#  u'COOPER',
#  u' ANGLE ON PAPER',
#  u' BACK TO SCENE',
#  u'TRUMAN',
# ...

# %%
scene = 0
scene_dict = {}

for line in scenes_chars:
    #print line
    scene_num = re.search('(\d+\w*)[\.\: ]', line)
  
    if scene_num is not None:
        #print scene_num.group(1), "scene num"
        print line
        scene = scene_num.group(1)
        scene_dict[scene] = {'scene_number': scene, 'characters':[], 'heading':{}}
        #inside or outside
        if "INT" in line:
            scene_dict[scene]['heading']['int_ext'] = 'INT'
        elif "EXT" in line:
            scene_dict[scene]['heading']['int_ext'] = 'EXT'
        #grabs location
        location = re.search('[A-Z]\. (.*) \-',line)
        if location is not None:
            scene_dict[scene]['heading']['location'] = location.group(1)
        #gets time
        time = re.search('- ([A-Z]+)$',line)
        if time is not None:
            scene_dict[scene]['heading']['time'] = time.group(1)
    elif scene == 0:
        pass
    else:
        if 'FADE' not in line and 'ACT' not in line and 'SCENE' not in line:
            if line not in scene_dict[scene]['characters']:
                scene_dict[scene]['characters'].append(line)

for a in scene_dict:
    print scene_dict[a]
# Out:
# 7700 Balboa Blvd
# 1. INT. GREAT NORTHERN DINING ROOM - DAY
# 2. INT. GREAT NORTHERN CORRIDOR - NIGHT
# 3. INT. GREAT NORTHERN DINING ROOM - DAY
# 4. EXT. HOSPITAL - DAY
# 4. INT. RONETTE PULASKI'S HOSPITAL ROOM - DAY
# 6: EXT. ONE-EYED JACK'S - DAY
# 7: INT. ONE-EYED JACK'S - DAY
# 8. EXT. APARTMENT HOUSE - DAY
# 9. INT. TREMOND APARTMENT - DAY
# 10. EXT. APARTMENT HOUSE - DAY
# 11. INT. BEN HORNE'S OFFICE - DAY
# 12. EXT. BLUE PINE LODGE - DAY
# 13. INT. BLUE PINE LODGE - DAY
# 14. INT. BLUE PINE LODGE KITCHEN - DAY
# 15. INT. BLUE PINE LODGE - DAY
# 16. INT. THE DOUBLE R DINER - DAY
# 17. INT. DINER - DAY
# 18. INT. THE DOUBLE R DINER - DAY
# 21. INT. THE DOUBLE R DINER - DAY
# 22. EXT. SHERIFF'S STATION - DAY
# 23. INT. SHERIFF'S STATION - DAY
# 24. INT. SHERIFF TRUMAN'S OFFICE - DAY
# 25. INT. SHERIFF'S STATION - DAY
# 26. INT. HOSPITAL ROOM - DAY
# 27. INT. GREAT NORTHERN HOTEL LOBBY - DAY
# 28. INT. BEN HORNE'S OFFICE - DAY
# 29. EXT. ONE-EYED JACK'S - NIGHT
# ...
