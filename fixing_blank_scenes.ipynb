# %%
import json
import csv

# %%
with open('twin_peaks_clean_locations_characters.json') as data_file:    
    data = json.load(data_file)

# %%
for a in data[0]['scenes']:
    if a['heading'] == {} and a['characters']==[]:
        print a['scene_number']
